# %%
#Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import geopandas as gpd
from pysheds.grid import Grid
import mplleaflet
# %matplotlib inline

# %%
#Open a digital elevation model 
grid = Grid.from_raster('kent_1_testE1.tif', data_name='dem')

# %%
#Define a function to plot the digital elevation model 
def plotFigure(data, label, cmap='Blues'):
    plt.figure(figsize=(12,10))
    plt.imshow(data, extent=grid.extent)
    plt.colorbar(label=label)
    plt.grid()

# %%
#Minnor slicing on borders to enhance colobars
elevDem=grid.dem[:-1,:-1]

# %%
plotFigure(elevDem, 'Elevation (m)')

# %%
# Detect depressions
depressions = grid.detect_depressions('dem')
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
# Plot depressions
plt.imshow(depressions)

# %%
# Fill depressions
grid.fill_depressions(data='dem', out_name='flooded_dem')
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
# Test result
depressions = grid.detect_depressions('flooded_dem')
plt.imshow(depressions)
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
# Detect flats
flats = grid.detect_flats('flooded_dem')
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
# Plot flats
plt.imshow(flats)

# %%
grid.resolve_flats(data='flooded_dem', out_name='inflated_dem')
plt.imshow(grid.inflated_dem[:-1,:-1])
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
# Create a flow direction grid
#N    NE    E    SE    S    SW    W    NW
dirmap = (64,  128,  1,   2,    4,   8,    16,  32)

# %%
grid.flowdir(data='inflated_dem', out_name='dir', dirmap=dirmap)
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
plotFigure(grid.dir,'Flow Direction','viridis')

# %%
# Specify discharge point
x, y = -122.222326,47.390963

# %%
# Delineate the catchment
grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
               recursionlimit=15000, xytype='label', nodata_out=0)
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-1a620f35e49d> in <module>
#       1 # Delineate the catchment
# ----> 2 grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
#       3                recursionlimit=15000, xytype='label', nodata_out=0)
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pysheds\grid.py in catchment(self, x, y, data, pour_value, out_name, dirmap, nodata_in, nodata_out, xytype, routing, recursionlimit, inplace, apply_mask, ignore_metadata, **kwargs)
#     889         if xytype in ('label', 'coordinate'):
#     890             if (x < xmin) or (x > xmax) or (y < ymin) or (y > ymax):
# --> 891                 raise ValueError('Pour point ({}, {}) is out of bounds for dataset with bbox {}.'
#     892                                 .format(x, y, (xmin, ymin, xmax, ymax)))
#     893         elif xytype == 'index':
#
# ValueError: Pour point (-122.222326, 47.390963) is out of bounds for dataset with bbox (363297.9425958842, 224747.47269494645, 377000.254000507, 235755.0419100849).
