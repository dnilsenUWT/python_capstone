# %%
#Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import geopandas as gpd
from pysheds.grid import Grid
import mplleaflet
# %matplotlib inline

# %%
#Open a digital elevation model 
grid = Grid.from_raster('WGSkent/WGSKent_Clip11.tif', data_name='dem')

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dem, extent=grid.extent, cmap='cubehelix', zorder=1)
plt.colorbar(label='Elevation (m)')
plt.grid(zorder=0)
plt.title('Digital elevation map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.tight_layout()
plt.savefig('conditioned_dem.png', bbox_inches='tight')

# %%
grid.resolve_flats('dem', out_name='inflated_dem')
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
#N    NE    E    SE    S    SW    W    NW
dirmap = (64,  128,  1,   2,    4,   8,    16,  32)

# %%
grid.flowdir(data='inflated_dem', out_name='dir', dirmap=dirmap)
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)

# %%
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dir, extent=grid.extent, cmap='viridis', zorder=2)
boundaries = ([0] + sorted(list(dirmap)))
plt.colorbar(boundaries= boundaries,
             values=sorted(dirmap))
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Flow direction grid')
plt.grid(zorder=-1)
plt.tight_layout()
plt.savefig('flow_direction.png', bbox_inches='tight')

# %%
grid.read_raster('kentDEM.tif', data_name='dir')

# %%
grid.dir
# Out:
# Raster([[367.06912, 367.14743, 367.54263, ..., 477.01175, 476.40085,
#          475.7945 ],
#         [367.1154 , 367.18915, 367.5239 , ..., 477.72128, 476.9882 ,
#          476.35657],
#         [367.16998, 367.20636, 367.48978, ..., 478.21536, 477.54456,
#          476.89993],
#         ...,
#         [439.42953, 439.41257, 439.43515, ..., 343.5874 , 343.91544,
#          344.33228],
#         [439.4536 , 439.4203 , 439.4284 , ..., 343.65414, 343.8644 ,
#          344.09683],
#         [439.4388 , 439.4152 , 439.42395, ..., 343.98395, 344.11325,
#          344.16425]], dtype=float32)

# %%
grid.dir.size
# Out:
# 180362408

# %%
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dir, extent=grid.extent, cmap='viridis', zorder=2)
boundaries = ([0] + sorted(list(dirmap)))
plt.colorbar(boundaries= boundaries,
             values=sorted(dirmap))
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Flow direction grid')
plt.grid(zorder=-1)
plt.tight_layout()

# %%
# Specify pour point
x, y = -122.222326, 47.390963

# Delineate the catchment
grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
               recursionlimit=15000, xytype='label', nodata_out=0)
# Out:
# C:\Users\super\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs.py:422: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   projstring = _prepare_from_string(projparams)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4d309a85ce62> in <module>
#       3
#       4 # Delineate the catchment
# ----> 5 grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
#       6                recursionlimit=15000, xytype='label', nodata_out=0)
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pysheds\grid.py in catchment(self, x, y, data, pour_value, out_name, dirmap, nodata_in, nodata_out, xytype, routing, recursionlimit, inplace, apply_mask, ignore_metadata, **kwargs)
#     889         if xytype in ('label', 'coordinate'):
#     890             if (x < xmin) or (x > xmax) or (y < ymin) or (y > ymax):
# --> 891                 raise ValueError('Pour point ({}, {}) is out of bounds for dataset with bbox {}.'
#     892                                 .format(x, y, (xmin, ymin, xmax, ymax)))
#     893         elif xytype == 'index':
#
# ValueError: Pour point (-122.222326, 47.390963) is out of bounds for dataset with bbox (363297.9425958842, 224747.47269494645, 377000.254000507, 235755.0419100849).
